# %% [markdown]
# # Reinforcement Learning: Collaboration and Competition
#
# Project 3, Udacity Deep Reinforcement Learning Nanodegree
#
# January 2019

# %%
import gym
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
PATH = "/Volumes/BC_Clutch/Dropbox/DeepRLND/rl_multiagent/"

# %%
data = pd.read_csv(PATH + "results/global_avg_reward.csv")

# %% [markdown]
# ### Tennis, MADDPG
#
# Note that average reward is over the most recent 100 episodes.

# %%
plt.plot(data.Step, data.Value)
plt.title(f"MADDPG Tennis: Average Agent Reward")
plt.ylabel("Average Reward")
plt.xlabel("Episode")
plt.savefig(PATH + f"charts/multiagent_results.png")
